# %% [markdown]
# # 🗂️ MapReduce Tutorial
# ## 1. 🔍 What is MapReduce?
# MapReduce is a programming model designed to process large-scale data in a distributed and parallel fashion.
#
# It consists of three major phases:
#
# - Map: Process input data and output intermediate key-value pairs.
#
# - Shuffle/Sort: Group all intermediate values by their key.
#
# - Reduce: Aggregate the values associated with each key to produce the final output​

# %% [markdown]
# ## 2. MapReduce Use Case: Word Count
# ### 2.1 Map Phase
# 1. Read input data line by line.
# 2. Tokenize each line into words.
# 3. Emit (word, 1) for each word

# %%
def map_phase(input_file):
    """Reads lines from input_file, yields (word, 1) for each word."""
    with open(input_file, 'r') as f:
        for line in f:
            words = line.strip().split()
            for word in words:
                yield (word.lower(), 1)   # Convert to lower case

# %% [markdown]
# ### 2.2 Shuffle/Sort Phase
# We need to group by the key (the word).

# %%
def shuffle_and_sort(mapped_data):
    """Groups the mapped data by key (word)."""
    sorted_data = {}
    for key, value in mapped_data:
        if key not in sorted_data:
            sorted_data[key] = []
        sorted_data[key].append(value)
    return sorted_data

# %% [markdown]
# ### 2.3 Reduce Phase
# For each word (key), we want to sum up the counts:

# %%
def reduce_phase(shuffled_data):
    """For each word key, sum up all the values."""
    reduced_data = {}
    for key, values in shuffled_data.items():
        reduced_data[key] = sum(values)
    return reduced_data

# %% [markdown]
# ### 2.4 Putting It All Together

# %%
# 1. Map
mapped = map_phase("input.txt")

# 2. Shuffle/Sort
shuffled = shuffle_and_sort(mapped)

# 3. Reduce
reduced_result = reduce_phase(shuffled)

# Print or save results
for word, count in reduced_result.items():
    print(f"{word}: {count}")
# Out:
# mapreduce: 2
# is: 3
# a: 3
# programming: 1
# model: 1
# for: 1
# processing: 1
# large: 1
# data: 2
# sets.: 1
# it: 1
# inspired: 1
# by: 1
# the: 4
# map: 2
# and: 2
# reduce: 2
# functions: 1
# commonly: 1
# used: 2
# in: 2
# functional: 1
# programming.: 1
# function: 2
# applies: 1
# transformation: 1
# to: 1
# each: 1
# element: 1
# of: 1
# collection,: 1
# while: 1
# aggregates: 1
# results.: 1
# enables: 1
# distributed: 1
# computing: 1
# across: 1
# many: 1
# machines.: 1
# this: 1
# approach: 1
# widely: 1
# big: 1
# processing,: 1
# including: 1
# log: 1
# analysis: 1
# indexing.: 1

# %% [markdown]
# ## 3. MapReduce Use Case: Calculate Mean and Variance
# ### 3.1 Map Phase: Each input data point emits `(value, value², count=1)`.

# %%
def map_phase(input_file):
    """Reads numbers from input_file and emits (x, x^2, 1) for each number."""
    with open(input_file, 'r') as f:
        for line in f:
            number = float(line.strip())  # Convert string to float
            yield (number, number ** 2, 1)  # Emit (x, x², count=1)

# %% [markdown]
# ### 3.2 Shuffle/Sort: Groups all mapped values together.

# %%
def shuffle_and_sort(mapped_data):
    """Since we are computing global statistics, this simply collects all mapped data."""
    sum_x = 0
    sum_x2 = 0
    count = 0
    for x, x2, c in mapped_data:
        sum_x += x
        sum_x2 += x2
        count += c
    return sum_x, sum_x2, count

# %% [markdown]
# ### 3.3 Reduce Step: Compute sum, sum of squares, and count to derive the mean and variance.

# %%
def reduce_phase(shuffled_data):
    """Computes mean and variance from aggregated data."""
    sum_x, sum_x2, count = shuffled_data
    if count == 0:
        return None, None  # Avoid division by zero

    mean = sum_x / count
    variance = (sum_x2 / count) - (mean ** 2)
    
    return mean, variance

# %% [markdown]
# ### 3.4 Putting It All Together

# %%
# 1. Map Phase
mapped = map_phase("numbers.txt")  # Input file with numbers

# 2. Shuffle & Sort Phase
shuffled = shuffle_and_sort(mapped)

# 3. Reduce Phase
mean, variance = reduce_phase(shuffled)

# Print Results
print(f"Mean: {mean}")
print(f"Variance: {variance}")
# Out:
# Mean: 30.813900000000007
# Variance: 149.0857957899999

# %% [markdown]
# ## 4. MapReduce Use Case: Linear Regression
# We want to fit a linear model: $$y = mx + b$$ using gradient descent, which iteratively updates parameters m (slope) and b (intercept) based on the gradient: $$m:= m - \alpha \frac{1}{N}\sum_i((mx_i+b-y_i)x_i)$$
# where:
# - $\alpha$ is the learning rate.
# - $N$ is the number of data points.
#
# ### 4.1 Mapper Function
# Each mapper reads a subset of the data and computes the partial gradients for m and b:

# %%
def map_phase(input_file, m, b):
    """Computes the partial gradients for m and b for each chunk."""
    with open(input_file, 'r') as f:
        for line in f:
            x, y = map(float, line.strip().split(','))  # Read X and Y
            error = (m * x + b) - y  # Compute error
            gradient_m = error * x   # Partial derivative w.r.t. m
            gradient_b = error       # Partial derivative w.r.t. b
            yield (1, (gradient_m, gradient_b, 1))  # Emit (key=1, values=(∂m, ∂b, count=1))

# %% [markdown]
# ### 4.2 Shuffle & Sort Phase
# This step groups all partial gradients from different mappers.

# %%
def shuffle_and_sort(mapped_data):
    """Aggregates partial gradients from all mappers."""
    sum_gradient_m = sum_gradient_b = count = 0
    for _, (gradient_m, gradient_b, c) in mapped_data:
        sum_gradient_m += gradient_m
        sum_gradient_b += gradient_b
        count += c
    return sum_gradient_m, sum_gradient_b, count

# %% [markdown]
# ### 4.3 Reducer Function
# The reducer aggregates the gradients and updates m and b:

# %%
def reduce_phase(shuffled_data, m, b, alpha):
    """Updates m and b using the averaged gradients."""
    sum_gradient_m, sum_gradient_b, count = shuffled_data
    if count == 0:
        return m, b  # Avoid division by zero

    # Compute the average gradients
    avg_gradient_m = sum_gradient_m / count
    avg_gradient_b = sum_gradient_b / count

    # Update parameters using gradient descent
    m -= alpha * avg_gradient_m
    b -= alpha * avg_gradient_b

    return m, b

# %% [markdown]
# ### 4.4 Put It All Together

# %%
# Hyperparameters
alpha = 0.1  # Learning rate
iterations = 500  # Number of iterations

# Initialize parameters
m, b = 0.0, 0.0  # Initial guess

# Run gradient descent for multiple iterations
for i in range(iterations):
    print(f"Iteration {i+1}: m = {m:.4f}, b = {b:.4f}")

    # Step 1: Map (Compute Partial Gradients)
    mapped = map_phase("data.csv", m, b)

    # Step 2: Shuffle & Sort (Aggregate Gradients)
    shuffled = shuffle_and_sort(mapped)

    # Step 3: Reduce (Update Parameters)
    m, b = reduce_phase(shuffled, m, b, alpha)

# Final Model
print(f"Final Linear Regression Model: y = {m:.4f}x + {b:.4f}")
# Out:
# Iteration 1: m = 0.0000, b = 0.0000
# Iteration 2: m = 2.1200, b = 0.5600
# Iteration 3: m = 1.7400, b = 0.4280
# Iteration 4: m = 1.8176, b = 0.4232
# Iteration 5: m = 1.8113, b = 0.3956
# Iteration 6: m = 1.8202, b = 0.3727
# Iteration 7: m = 1.8262, b = 0.3493
# Iteration 8: m = 1.8326, b = 0.3265
# Iteration 9: m = 1.8388, b = 0.3041
# Iteration 10: m = 1.8449, b = 0.2821
# Iteration 11: m = 1.8509, b = 0.2604
# Iteration 12: m = 1.8568, b = 0.2391
# Iteration 13: m = 1.8626, b = 0.2181
# Iteration 14: m = 1.8683, b = 0.1976
# Iteration 15: m = 1.8739, b = 0.1773
# Iteration 16: m = 1.8794, b = 0.1574
# Iteration 17: m = 1.8848, b = 0.1378
# Iteration 18: m = 1.8902, b = 0.1186
# Iteration 19: m = 1.8954, b = 0.0997
# Iteration 20: m = 1.9006, b = 0.0811
# Iteration 21: m = 1.9056, b = 0.0628
# Iteration 22: m = 1.9106, b = 0.0449
# Iteration 23: m = 1.9155, b = 0.0272
# Iteration 24: m = 1.9203, b = 0.0098
# Iteration 25: m = 1.9250, b = -0.0072
# Iteration 26: m = 1.9297, b = -0.0240
# Iteration 27: m = 1.9342, b = -0.0405
# Iteration 28: m = 1.9387, b = -0.0567
# Iteration 29: m = 1.9431, b = -0.0727
# Iteration 30: m = 1.9475, b = -0.0884
# Iteration 31: m = 1.9518, b = -0.1038
# Iteration 32: m = 1.9560, b = -0.1189
# Iteration 33: m = 1.9601, b = -0.1338
# Iteration 34: m = 1.9641, b = -0.1485
# Iteration 35: m = 1.9681, b = -0.1629
# Iteration 36: m = 1.9720, b = -0.1770
# Iteration 37: m = 1.9759, b = -0.1909
# Iteration 38: m = 1.9797, b = -0.2046
# Iteration 39: m = 1.9834, b = -0.2180
# Iteration 40: m = 1.9871, b = -0.2313
# Iteration 41: m = 1.9907, b = -0.2443
# Iteration 42: m = 1.9942, b = -0.2570
# Iteration 43: m = 1.9977, b = -0.2696
# Iteration 44: m = 2.0011, b = -0.2819
# Iteration 45: m = 2.0045, b = -0.2941
# Iteration 46: m = 2.0078, b = -0.3060
# Iteration 47: m = 2.0110, b = -0.3177
# Iteration 48: m = 2.0142, b = -0.3293
# Iteration 49: m = 2.0174, b = -0.3406
# Iteration 50: m = 2.0204, b = -0.3518
# Iteration 51: m = 2.0235, b = -0.3627
# Iteration 52: m = 2.0265, b = -0.3735
# Iteration 53: m = 2.0294, b = -0.3841
# Iteration 54: m = 2.0323, b = -0.3945
# Iteration 55: m = 2.0351, b = -0.4047
# Iteration 56: m = 2.0379, b = -0.4148
# Iteration 57: m = 2.0406, b = -0.4247
# Iteration 58: m = 2.0433, b = -0.4344
# Iteration 59: m = 2.0460, b = -0.4440
# Iteration 60: m = 2.0486, b = -0.4534
# Iteration 61: m = 2.0512, b = -0.4626
# Iteration 62: m = 2.0537, b = -0.4717
# Iteration 63: m = 2.0561, b = -0.4806
# Iteration 64: m = 2.0586, b = -0.4894
# Iteration 65: m = 2.0610, b = -0.4980
# Iteration 66: m = 2.0633, b = -0.5065
# Iteration 67: m = 2.0656, b = -0.5149
# Iteration 68: m = 2.0679, b = -0.5231
# Iteration 69: m = 2.0701, b = -0.5311
# Iteration 70: m = 2.0723, b = -0.5391
# Iteration 71: m = 2.0745, b = -0.5469
# Iteration 72: m = 2.0766, b = -0.5545
# Iteration 73: m = 2.0787, b = -0.5620
# Iteration 74: m = 2.0807, b = -0.5694
# Iteration 75: m = 2.0828, b = -0.5767
# Iteration 76: m = 2.0847, b = -0.5839
# Iteration 77: m = 2.0867, b = -0.5909
# Iteration 78: m = 2.0886, b = -0.5978
# Iteration 79: m = 2.0905, b = -0.6046
# Iteration 80: m = 2.0923, b = -0.6113
# Iteration 81: m = 2.0942, b = -0.6179
# Iteration 82: m = 2.0959, b = -0.6243
# Iteration 83: m = 2.0977, b = -0.6307
# Iteration 84: m = 2.0994, b = -0.6369
# Iteration 85: m = 2.1011, b = -0.6431
# Iteration 86: m = 2.1028, b = -0.6491
# Iteration 87: m = 2.1045, b = -0.6550
# Iteration 88: m = 2.1061, b = -0.6609
# Iteration 89: m = 2.1077, b = -0.6666
# Iteration 90: m = 2.1092, b = -0.6722
# Iteration 91: m = 2.1108, b = -0.6778
# Iteration 92: m = 2.1123, b = -0.6832
# Iteration 93: m = 2.1137, b = -0.6886
# Iteration 94: m = 2.1152, b = -0.6938
# Iteration 95: m = 2.1166, b = -0.6990
# Iteration 96: m = 2.1180, b = -0.7041
# Iteration 97: m = 2.1194, b = -0.7091
# Iteration 98: m = 2.1208, b = -0.7140
# Iteration 99: m = 2.1221, b = -0.7189
# Iteration 100: m = 2.1234, b = -0.7236
# Iteration 101: m = 2.1247, b = -0.7283
# Iteration 102: m = 2.1260, b = -0.7329
# Iteration 103: m = 2.1273, b = -0.7374
# Iteration 104: m = 2.1285, b = -0.7418
# Iteration 105: m = 2.1297, b = -0.7462
# Iteration 106: m = 2.1309, b = -0.7505
# Iteration 107: m = 2.1321, b = -0.7547
# Iteration 108: m = 2.1332, b = -0.7589
# Iteration 109: m = 2.1343, b = -0.7629
# Iteration 110: m = 2.1354, b = -0.7669
# Iteration 111: m = 2.1365, b = -0.7709
# Iteration 112: m = 2.1376, b = -0.7748
# Iteration 113: m = 2.1387, b = -0.7786
# Iteration 114: m = 2.1397, b = -0.7823
# Iteration 115: m = 2.1407, b = -0.7860
# Iteration 116: m = 2.1417, b = -0.7896
# Iteration 117: m = 2.1427, b = -0.7932
# Iteration 118: m = 2.1437, b = -0.7967
# Iteration 119: m = 2.1446, b = -0.8001
# Iteration 120: m = 2.1456, b = -0.8035
# Iteration 121: m = 2.1465, b = -0.8068
# Iteration 122: m = 2.1474, b = -0.8101
# Iteration 123: m = 2.1483, b = -0.8133
# Iteration 124: m = 2.1492, b = -0.8164
# Iteration 125: m = 2.1500, b = -0.8195
# Iteration 126: m = 2.1509, b = -0.8226
# Iteration 127: m = 2.1517, b = -0.8256
# Iteration 128: m = 2.1525, b = -0.8285
# Iteration 129: m = 2.1533, b = -0.8314
# Iteration 130: m = 2.1541, b = -0.8343
# Iteration 131: m = 2.1549, b = -0.8371
# Iteration 132: m = 2.1556, b = -0.8398
# Iteration 133: m = 2.1564, b = -0.8425
# Iteration 134: m = 2.1571, b = -0.8452
# Iteration 135: m = 2.1578, b = -0.8478
# Iteration 136: m = 2.1586, b = -0.8504
# Iteration 137: m = 2.1593, b = -0.8529
# Iteration 138: m = 2.1600, b = -0.8554
# Iteration 139: m = 2.1606, b = -0.8579
# Iteration 140: m = 2.1613, b = -0.8603
# Iteration 141: m = 2.1619, b = -0.8626
# Iteration 142: m = 2.1626, b = -0.8649
# Iteration 143: m = 2.1632, b = -0.8672
# Iteration 144: m = 2.1638, b = -0.8695
# Iteration 145: m = 2.1645, b = -0.8717
# Iteration 146: m = 2.1651, b = -0.8738
# Iteration 147: m = 2.1656, b = -0.8760
# Iteration 148: m = 2.1662, b = -0.8781
# Iteration 149: m = 2.1668, b = -0.8801
# Iteration 150: m = 2.1674, b = -0.8822
# Iteration 151: m = 2.1679, b = -0.8842
# Iteration 152: m = 2.1685, b = -0.8861
# Iteration 153: m = 2.1690, b = -0.8880
# Iteration 154: m = 2.1695, b = -0.8899
# Iteration 155: m = 2.1700, b = -0.8918
# Iteration 156: m = 2.1705, b = -0.8936
# Iteration 157: m = 2.1710, b = -0.8954
# Iteration 158: m = 2.1715, b = -0.8972
# Iteration 159: m = 2.1720, b = -0.8989
# Iteration 160: m = 2.1725, b = -0.9006
# Iteration 161: m = 2.1729, b = -0.9023
# Iteration 162: m = 2.1734, b = -0.9040
# Iteration 163: m = 2.1738, b = -0.9056
# Iteration 164: m = 2.1743, b = -0.9072
# Iteration 165: m = 2.1747, b = -0.9088
# Iteration 166: m = 2.1752, b = -0.9103
# Iteration 167: m = 2.1756, b = -0.9118
# Iteration 168: m = 2.1760, b = -0.9133
# Iteration 169: m = 2.1764, b = -0.9148
# Iteration 170: m = 2.1768, b = -0.9162
# Iteration 171: m = 2.1772, b = -0.9176
# Iteration 172: m = 2.1776, b = -0.9190
# Iteration 173: m = 2.1779, b = -0.9204
# Iteration 174: m = 2.1783, b = -0.9217
# Iteration 175: m = 2.1787, b = -0.9231
# Iteration 176: m = 2.1790, b = -0.9244
# Iteration 177: m = 2.1794, b = -0.9256
# Iteration 178: m = 2.1798, b = -0.9269
# Iteration 179: m = 2.1801, b = -0.9281
# Iteration 180: m = 2.1804, b = -0.9293
# Iteration 181: m = 2.1808, b = -0.9305
# Iteration 182: m = 2.1811, b = -0.9317
# Iteration 183: m = 2.1814, b = -0.9329
# Iteration 184: m = 2.1817, b = -0.9340
# Iteration 185: m = 2.1820, b = -0.9351
# Iteration 186: m = 2.1823, b = -0.9362
# Iteration 187: m = 2.1826, b = -0.9373
# Iteration 188: m = 2.1829, b = -0.9384
# Iteration 189: m = 2.1832, b = -0.9394
# Iteration 190: m = 2.1835, b = -0.9404
# Iteration 191: m = 2.1838, b = -0.9414
# Iteration 192: m = 2.1841, b = -0.9424
# Iteration 193: m = 2.1843, b = -0.9434
# Iteration 194: m = 2.1846, b = -0.9443
# Iteration 195: m = 2.1848, b = -0.9453
# Iteration 196: m = 2.1851, b = -0.9462
# Iteration 197: m = 2.1854, b = -0.9471
# Iteration 198: m = 2.1856, b = -0.9480
# Iteration 199: m = 2.1858, b = -0.9489
# Iteration 200: m = 2.1861, b = -0.9498
# Iteration 201: m = 2.1863, b = -0.9506
# Iteration 202: m = 2.1866, b = -0.9514
# Iteration 203: m = 2.1868, b = -0.9523
# Iteration 204: m = 2.1870, b = -0.9531
# Iteration 205: m = 2.1872, b = -0.9539
# Iteration 206: m = 2.1874, b = -0.9546
# Iteration 207: m = 2.1876, b = -0.9554
# Iteration 208: m = 2.1879, b = -0.9562
# Iteration 209: m = 2.1881, b = -0.9569
# Iteration 210: m = 2.1883, b = -0.9576
# Iteration 211: m = 2.1885, b = -0.9583
# Iteration 212: m = 2.1887, b = -0.9591
# Iteration 213: m = 2.1889, b = -0.9597
# Iteration 214: m = 2.1890, b = -0.9604
# Iteration 215: m = 2.1892, b = -0.9611
# Iteration 216: m = 2.1894, b = -0.9618
# Iteration 217: m = 2.1896, b = -0.9624
# Iteration 218: m = 2.1898, b = -0.9630
# Iteration 219: m = 2.1899, b = -0.9637
# Iteration 220: m = 2.1901, b = -0.9643
# Iteration 221: m = 2.1903, b = -0.9649
# Iteration 222: m = 2.1904, b = -0.9655
# Iteration 223: m = 2.1906, b = -0.9661
# Iteration 224: m = 2.1908, b = -0.9666
# Iteration 225: m = 2.1909, b = -0.9672
# Iteration 226: m = 2.1911, b = -0.9677
# Iteration 227: m = 2.1912, b = -0.9683
# Iteration 228: m = 2.1914, b = -0.9688
# Iteration 229: m = 2.1915, b = -0.9694
# Iteration 230: m = 2.1917, b = -0.9699
# Iteration 231: m = 2.1918, b = -0.9704
# Iteration 232: m = 2.1919, b = -0.9709
# Iteration 233: m = 2.1921, b = -0.9714
# Iteration 234: m = 2.1922, b = -0.9719
# Iteration 235: m = 2.1923, b = -0.9723
# Iteration 236: m = 2.1925, b = -0.9728
# Iteration 237: m = 2.1926, b = -0.9733
# Iteration 238: m = 2.1927, b = -0.9737
# Iteration 239: m = 2.1928, b = -0.9742
# Iteration 240: m = 2.1930, b = -0.9746
# Iteration 241: m = 2.1931, b = -0.9750
# Iteration 242: m = 2.1932, b = -0.9754
# Iteration 243: m = 2.1933, b = -0.9759
# Iteration 244: m = 2.1934, b = -0.9763
# Iteration 245: m = 2.1935, b = -0.9767
# Iteration 246: m = 2.1936, b = -0.9771
# Iteration 247: m = 2.1938, b = -0.9775
# Iteration 248: m = 2.1939, b = -0.9778
# Iteration 249: m = 2.1940, b = -0.9782
# Iteration 250: m = 2.1941, b = -0.9786
# Iteration 251: m = 2.1942, b = -0.9789
# Iteration 252: m = 2.1943, b = -0.9793
# Iteration 253: m = 2.1944, b = -0.9796
# Iteration 254: m = 2.1945, b = -0.9800
# Iteration 255: m = 2.1946, b = -0.9803
# Iteration 256: m = 2.1946, b = -0.9807
# Iteration 257: m = 2.1947, b = -0.9810
# Iteration 258: m = 2.1948, b = -0.9813
# Iteration 259: m = 2.1949, b = -0.9816
# Iteration 260: m = 2.1950, b = -0.9819
# Iteration 261: m = 2.1951, b = -0.9822
# Iteration 262: m = 2.1952, b = -0.9825
# Iteration 263: m = 2.1952, b = -0.9828
# Iteration 264: m = 2.1953, b = -0.9831
# Iteration 265: m = 2.1954, b = -0.9834
# Iteration 266: m = 2.1955, b = -0.9837
# Iteration 267: m = 2.1956, b = -0.9840
# Iteration 268: m = 2.1956, b = -0.9842
# Iteration 269: m = 2.1957, b = -0.9845
# Iteration 270: m = 2.1958, b = -0.9848
# Iteration 271: m = 2.1959, b = -0.9850
# Iteration 272: m = 2.1959, b = -0.9853
# Iteration 273: m = 2.1960, b = -0.9855
# Iteration 274: m = 2.1961, b = -0.9858
# Iteration 275: m = 2.1961, b = -0.9860
# Iteration 276: m = 2.1962, b = -0.9862
# Iteration 277: m = 2.1963, b = -0.9865
# Iteration 278: m = 2.1963, b = -0.9867
# Iteration 279: m = 2.1964, b = -0.9869
# Iteration 280: m = 2.1964, b = -0.9872
# Iteration 281: m = 2.1965, b = -0.9874
# Iteration 282: m = 2.1966, b = -0.9876
# Iteration 283: m = 2.1966, b = -0.9878
# Iteration 284: m = 2.1967, b = -0.9880
# Iteration 285: m = 2.1967, b = -0.9882
# Iteration 286: m = 2.1968, b = -0.9884
# Iteration 287: m = 2.1968, b = -0.9886
# Iteration 288: m = 2.1969, b = -0.9888
# Iteration 289: m = 2.1969, b = -0.9890
# Iteration 290: m = 2.1970, b = -0.9892
# Iteration 291: m = 2.1971, b = -0.9894
# Iteration 292: m = 2.1971, b = -0.9895
# Iteration 293: m = 2.1971, b = -0.9897
# Iteration 294: m = 2.1972, b = -0.9899
# Iteration 295: m = 2.1972, b = -0.9901
# Iteration 296: m = 2.1973, b = -0.9902
# Iteration 297: m = 2.1973, b = -0.9904
# Iteration 298: m = 2.1974, b = -0.9905
# Iteration 299: m = 2.1974, b = -0.9907
# Iteration 300: m = 2.1975, b = -0.9909
# Iteration 301: m = 2.1975, b = -0.9910
# Iteration 302: m = 2.1976, b = -0.9912
# Iteration 303: m = 2.1976, b = -0.9913
# Iteration 304: m = 2.1976, b = -0.9915
# Iteration 305: m = 2.1977, b = -0.9916
# Iteration 306: m = 2.1977, b = -0.9918
# Iteration 307: m = 2.1978, b = -0.9919
# Iteration 308: m = 2.1978, b = -0.9920
# Iteration 309: m = 2.1978, b = -0.9922
# Iteration 310: m = 2.1979, b = -0.9923
# Iteration 311: m = 2.1979, b = -0.9924
# Iteration 312: m = 2.1979, b = -0.9926
# Iteration 313: m = 2.1980, b = -0.9927
# Iteration 314: m = 2.1980, b = -0.9928
# Iteration 315: m = 2.1980, b = -0.9929
# Iteration 316: m = 2.1981, b = -0.9930
# Iteration 317: m = 2.1981, b = -0.9932
# Iteration 318: m = 2.1981, b = -0.9933
# Iteration 319: m = 2.1982, b = -0.9934
# Iteration 320: m = 2.1982, b = -0.9935
# Iteration 321: m = 2.1982, b = -0.9936
# Iteration 322: m = 2.1983, b = -0.9937
# Iteration 323: m = 2.1983, b = -0.9938
# Iteration 324: m = 2.1983, b = -0.9939
# Iteration 325: m = 2.1983, b = -0.9940
# Iteration 326: m = 2.1984, b = -0.9941
# Iteration 327: m = 2.1984, b = -0.9942
# Iteration 328: m = 2.1984, b = -0.9943
# Iteration 329: m = 2.1985, b = -0.9944
# Iteration 330: m = 2.1985, b = -0.9945
# Iteration 331: m = 2.1985, b = -0.9946
# Iteration 332: m = 2.1985, b = -0.9947
# Iteration 333: m = 2.1986, b = -0.9948
# Iteration 334: m = 2.1986, b = -0.9949
# Iteration 335: m = 2.1986, b = -0.9950
# Iteration 336: m = 2.1986, b = -0.9951
# Iteration 337: m = 2.1987, b = -0.9951
# Iteration 338: m = 2.1987, b = -0.9952
# Iteration 339: m = 2.1987, b = -0.9953
# Iteration 340: m = 2.1987, b = -0.9954
# Iteration 341: m = 2.1987, b = -0.9955
# Iteration 342: m = 2.1988, b = -0.9955
# Iteration 343: m = 2.1988, b = -0.9956
# Iteration 344: m = 2.1988, b = -0.9957
# Iteration 345: m = 2.1988, b = -0.9958
# Iteration 346: m = 2.1988, b = -0.9958
# Iteration 347: m = 2.1989, b = -0.9959
# Iteration 348: m = 2.1989, b = -0.9960
# Iteration 349: m = 2.1989, b = -0.9960
# Iteration 350: m = 2.1989, b = -0.9961
# Iteration 351: m = 2.1989, b = -0.9962
# Iteration 352: m = 2.1990, b = -0.9962
# Iteration 353: m = 2.1990, b = -0.9963
# Iteration 354: m = 2.1990, b = -0.9964
# Iteration 355: m = 2.1990, b = -0.9964
# Iteration 356: m = 2.1990, b = -0.9965
# Iteration 357: m = 2.1990, b = -0.9965
# Iteration 358: m = 2.1991, b = -0.9966
# Iteration 359: m = 2.1991, b = -0.9967
# Iteration 360: m = 2.1991, b = -0.9967
# Iteration 361: m = 2.1991, b = -0.9968
# Iteration 362: m = 2.1991, b = -0.9968
# Iteration 363: m = 2.1991, b = -0.9969
# Iteration 364: m = 2.1992, b = -0.9969
# Iteration 365: m = 2.1992, b = -0.9970
# Iteration 366: m = 2.1992, b = -0.9970
# Iteration 367: m = 2.1992, b = -0.9971
# Iteration 368: m = 2.1992, b = -0.9971
# Iteration 369: m = 2.1992, b = -0.9972
# Iteration 370: m = 2.1992, b = -0.9972
# Iteration 371: m = 2.1992, b = -0.9973
# Iteration 372: m = 2.1993, b = -0.9973
# Iteration 373: m = 2.1993, b = -0.9974
# Iteration 374: m = 2.1993, b = -0.9974
# Iteration 375: m = 2.1993, b = -0.9975
# Iteration 376: m = 2.1993, b = -0.9975
# Iteration 377: m = 2.1993, b = -0.9975
# Iteration 378: m = 2.1993, b = -0.9976
# Iteration 379: m = 2.1993, b = -0.9976
# Iteration 380: m = 2.1994, b = -0.9977
# Iteration 381: m = 2.1994, b = -0.9977
# Iteration 382: m = 2.1994, b = -0.9977
# Iteration 383: m = 2.1994, b = -0.9978
# Iteration 384: m = 2.1994, b = -0.9978
# Iteration 385: m = 2.1994, b = -0.9979
# Iteration 386: m = 2.1994, b = -0.9979
# Iteration 387: m = 2.1994, b = -0.9979
# Iteration 388: m = 2.1994, b = -0.9980
# Iteration 389: m = 2.1994, b = -0.9980
# Iteration 390: m = 2.1995, b = -0.9980
# Iteration 391: m = 2.1995, b = -0.9981
# Iteration 392: m = 2.1995, b = -0.9981
# Iteration 393: m = 2.1995, b = -0.9981
# Iteration 394: m = 2.1995, b = -0.9982
# Iteration 395: m = 2.1995, b = -0.9982
# Iteration 396: m = 2.1995, b = -0.9982
# Iteration 397: m = 2.1995, b = -0.9983
# Iteration 398: m = 2.1995, b = -0.9983
# Iteration 399: m = 2.1995, b = -0.9983
# Iteration 400: m = 2.1995, b = -0.9983
# Iteration 401: m = 2.1995, b = -0.9984
# Iteration 402: m = 2.1996, b = -0.9984
# Iteration 403: m = 2.1996, b = -0.9984
# Iteration 404: m = 2.1996, b = -0.9984
# Iteration 405: m = 2.1996, b = -0.9985
# Iteration 406: m = 2.1996, b = -0.9985
# Iteration 407: m = 2.1996, b = -0.9985
# Iteration 408: m = 2.1996, b = -0.9986
# Iteration 409: m = 2.1996, b = -0.9986
# Iteration 410: m = 2.1996, b = -0.9986
# Iteration 411: m = 2.1996, b = -0.9986
# Iteration 412: m = 2.1996, b = -0.9986
# Iteration 413: m = 2.1996, b = -0.9987
# Iteration 414: m = 2.1996, b = -0.9987
# Iteration 415: m = 2.1996, b = -0.9987
# Iteration 416: m = 2.1996, b = -0.9987
# Iteration 417: m = 2.1997, b = -0.9988
# Iteration 418: m = 2.1997, b = -0.9988
# Iteration 419: m = 2.1997, b = -0.9988
# Iteration 420: m = 2.1997, b = -0.9988
# Iteration 421: m = 2.1997, b = -0.9988
# Iteration 422: m = 2.1997, b = -0.9989
# Iteration 423: m = 2.1997, b = -0.9989
# Iteration 424: m = 2.1997, b = -0.9989
# Iteration 425: m = 2.1997, b = -0.9989
# Iteration 426: m = 2.1997, b = -0.9989
# Iteration 427: m = 2.1997, b = -0.9990
# Iteration 428: m = 2.1997, b = -0.9990
# Iteration 429: m = 2.1997, b = -0.9990
# Iteration 430: m = 2.1997, b = -0.9990
# Iteration 431: m = 2.1997, b = -0.9990
# Iteration 432: m = 2.1997, b = -0.9990
# Iteration 433: m = 2.1997, b = -0.9991
# Iteration 434: m = 2.1997, b = -0.9991
# Iteration 435: m = 2.1997, b = -0.9991
# Iteration 436: m = 2.1998, b = -0.9991
# Iteration 437: m = 2.1998, b = -0.9991
# Iteration 438: m = 2.1998, b = -0.9991
# Iteration 439: m = 2.1998, b = -0.9991
# Iteration 440: m = 2.1998, b = -0.9992
# Iteration 441: m = 2.1998, b = -0.9992
# Iteration 442: m = 2.1998, b = -0.9992
# Iteration 443: m = 2.1998, b = -0.9992
# Iteration 444: m = 2.1998, b = -0.9992
# Iteration 445: m = 2.1998, b = -0.9992
# Iteration 446: m = 2.1998, b = -0.9992
# Iteration 447: m = 2.1998, b = -0.9993
# Iteration 448: m = 2.1998, b = -0.9993
# Iteration 449: m = 2.1998, b = -0.9993
# Iteration 450: m = 2.1998, b = -0.9993
# Iteration 451: m = 2.1998, b = -0.9993
# Iteration 452: m = 2.1998, b = -0.9993
# Iteration 453: m = 2.1998, b = -0.9993
# Iteration 454: m = 2.1998, b = -0.9993
# Iteration 455: m = 2.1998, b = -0.9993
# Iteration 456: m = 2.1998, b = -0.9994
# Iteration 457: m = 2.1998, b = -0.9994
# Iteration 458: m = 2.1998, b = -0.9994
# Iteration 459: m = 2.1998, b = -0.9994
# Iteration 460: m = 2.1998, b = -0.9994
# Iteration 461: m = 2.1998, b = -0.9994
# Iteration 462: m = 2.1998, b = -0.9994
# Iteration 463: m = 2.1998, b = -0.9994
# Iteration 464: m = 2.1998, b = -0.9994
# Iteration 465: m = 2.1998, b = -0.9995
# Iteration 466: m = 2.1999, b = -0.9995
# Iteration 467: m = 2.1999, b = -0.9995
# Iteration 468: m = 2.1999, b = -0.9995
# Iteration 469: m = 2.1999, b = -0.9995
# Iteration 470: m = 2.1999, b = -0.9995
# Iteration 471: m = 2.1999, b = -0.9995
# Iteration 472: m = 2.1999, b = -0.9995
# Iteration 473: m = 2.1999, b = -0.9995
# Iteration 474: m = 2.1999, b = -0.9995
# Iteration 475: m = 2.1999, b = -0.9995
# Iteration 476: m = 2.1999, b = -0.9995
# Iteration 477: m = 2.1999, b = -0.9996
# Iteration 478: m = 2.1999, b = -0.9996
# Iteration 479: m = 2.1999, b = -0.9996
# Iteration 480: m = 2.1999, b = -0.9996
# Iteration 481: m = 2.1999, b = -0.9996
# Iteration 482: m = 2.1999, b = -0.9996
# Iteration 483: m = 2.1999, b = -0.9996
# Iteration 484: m = 2.1999, b = -0.9996
# Iteration 485: m = 2.1999, b = -0.9996
# Iteration 486: m = 2.1999, b = -0.9996
# Iteration 487: m = 2.1999, b = -0.9996
# Iteration 488: m = 2.1999, b = -0.9996
# Iteration 489: m = 2.1999, b = -0.9996
# Iteration 490: m = 2.1999, b = -0.9996
# Iteration 491: m = 2.1999, b = -0.9996
# Iteration 492: m = 2.1999, b = -0.9997
# Iteration 493: m = 2.1999, b = -0.9997
# Iteration 494: m = 2.1999, b = -0.9997
# Iteration 495: m = 2.1999, b = -0.9997
# Iteration 496: m = 2.1999, b = -0.9997
# Iteration 497: m = 2.1999, b = -0.9997
# Iteration 498: m = 2.1999, b = -0.9997
# Iteration 499: m = 2.1999, b = -0.9997
# Iteration 500: m = 2.1999, b = -0.9997
# Final Linear Regression Model: y = 2.1999x + -0.9997

# %% [markdown]
# ## 5. ✅ Advantages and Limitations
# ✅ Advantages
# - Simplifies parallel programming.
#
# - Scales horizontally across distributed systems.
#
# - Built-in fault tolerance.
#
# ❌ Limitations
# - Poor performance for iterative or real-time algorithms.
#
# - Less flexible than general-purpose distributed computing frameworks​

# %% [markdown]
# ## Homework Assignments
# Please use the same `input.txt` file in section 2, modify mapper/ Reducer function to count all the words with length $>=4$.

# %%
def map_phase(input_file):
    """Reads lines from input_file, yields (word, 1) for each word."""
    with open(input_file, 'r') as f:
        for line in f:
            words = line.strip().split()
            for word in words:
                if len(word) >= 4:
                    yield (word.lower(), 1)   # Convert to lower case

# %%
def shuffle_and_sort(mapped_data):
    """Groups the mapped data by key (word)."""
    sorted_data = {}
    for key, value in mapped_data:
        if key not in sorted_data:
            sorted_data[key] = []
        sorted_data[key].append(value)
    return sorted_data

# %%
def reduce_phase(shuffled_data):
    """For each word key, sum up all the values."""
    reduced_data = {}
    for key, values in shuffled_data.items():
        reduced_data[key] = sum(values)
    return reduced_data

# %%
# 1. Map
mapped = map_phase("input.txt")

# 2. Shuffle/Sort
shuffled = shuffle_and_sort(mapped)

# 3. Reduce
reduced_result = reduce_phase(shuffled)

# Print or save results
for word, count in reduced_result.items():
    print(f"{word}: {count}")
# Out:
# mapreduce: 2
# programming: 1
# model: 1
# processing: 1
# large: 1
# data: 2
# sets.: 1
# inspired: 1
# reduce: 2
# functions: 1
# commonly: 1
# used: 2
# functional: 1
# programming.: 1
# function: 2
# applies: 1
# transformation: 1
# each: 1
# element: 1
# collection,: 1
# while: 1
# aggregates: 1
# results.: 1
# enables: 1
# distributed: 1
# computing: 1
# across: 1
# many: 1
# machines.: 1
# this: 1
# approach: 1
# widely: 1
# processing,: 1
# including: 1
# analysis: 1
# indexing.: 1
